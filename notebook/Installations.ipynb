# %%
# %pip install "numpy<2"
# %pip install matplotlib
# %pip install LinearRegression
# %pip install yfinance
# %pip install pandas
# %pip install scikit-learn

# %%
# %pip show numpy
# %pip show transformers

# %%
# %pip install python-dotenv

# %%
# %pip install langchain-google-genai google-generativeai

# %%
# %pip install "numpy<2" --force-reinstall

# %%
# %pip install -U langchain==1.0.0
# %pip install -U langgraph==1.0.0

# Optional connectors
# %pip install -U langchain-openai
# %pip install -U langchain-anthropic
# %pip install "langgraph-checkpoint<3.0.0" "langgraph-checkpoint-sqlite<3.0.0"

# %%
# %pip install --upgrade langgraph langgraph-checkpoint-sqlite

# %%
# %pip show langgraph
# %pip show langgraph-checkpoint-sqlite
# %pip show langchain-core
# Out:
# Name: langgraph
# Version: 1.0.4
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page: https://docs.langchain.com/oss/python/langgraph/overview
# Author:
# Author-email:
# License-Expression: MIT
# Location: /Users/mandeep/myprojects/ai_finance_assistant/venv/lib/python3.12/site-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by: langchain
# Note: you may need to restart the kernel to use updated packages.
# Name: langgraph-checkpoint-sqlite
# Version: 3.0.1
# Summary: Library with a SQLite implementation of LangGraph checkpoint saver.
# Home-page:
# Author:
# Author-email:
# License-Expression: MIT
# Location: /Users/mandeep/myprojects/ai_finance_assistant/venv/lib/python3.12/site-packages
# Requires: aiosqlite, langgraph-checkpoint, sqlite-vec
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# Name: langchain-core
# Version: 1.1.3
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /Users/mandeep/myprojects/ai_finance_assistant/venv/lib/python3.12/site-packages
# Requires: jsonpatch, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions, uuid-utils
# Required-by: langchain, langchain-anthropic, langchain-google-genai, langchain-openai, langgraph, langgraph-checkpoint, langgraph-prebuilt
# Note: you may need to restart the kernel to use updated packages.

# %%
# Optional vector store dependencies (for RAG)
# %pip install -U faiss-cpu
# %pip install -U chromadb
#%pip install -U sentence-transformers # deleted due to a version mismatch

# UI Interface
# %pip install streamlit

# %%
# to convert .ipynb to .py
# %pip install nbconvert

# %%
# LLM related installs
# %pip install google-generativeai
# %pip install langchain-google-genai

# %%
# %pip install langchain-google-genai

# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import sklearn.linear_model

# Utility function
def print_package_info(pkg, name=None):
    name = name or pkg.__name__
    version = getattr(pkg, "__version__", "N/A")
    location = os.path.dirname(pkg.__file__)
    print(f"{name} version: {version}\nLocation: {location}\n")

# Examples
print_package_info(np, "numpy")
print_package_info(pd, "pandas")
print_package_info(matplotlib, "matplotlib")
print_package_info(sklearn, "scikit-learn")
print_package_info(sklearn.linear_model, "sklearn.linear_model")

# %%
# %pip install -r /Users/mandeep/myprojects/ai_finance_assistant/requirements.txt
